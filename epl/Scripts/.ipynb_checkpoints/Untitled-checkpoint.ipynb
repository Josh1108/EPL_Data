# %%
import praw
import pandas as pd
import datetime as dt
import logging
import numpy as np
from numpy import random
import nltk
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import re
from bs4 import BeautifulSoup
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics import classification_report

# %%
def logisticreg(X_train, X_test, y_train, y_test):
    from sklearn.linear_model import LogisticRegression
    logmodel = LogisticRegression(C=1e3)
    logmodel.fit(X_train,y_train)
    predictions = logmodel.predict(X_test)
    from sklearn.metrics import classification_report
    print(classification_report(y_test,predictions))
    from sklearn.metrics import confusion_matrix
    print(confusion_matrix(y_test,predictions))
    score = logmodel.score(X_test, y_test)
    print(score)

# %%
def train_test(X,y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 42)

#     print("Results of Logistic Regression")
#     logisticreg(X_train, X_test, y_train, y_test)
    
#     print("svm")
#     svm(X_train, X_test, y_train, y_test)
    print('random forest')
    rand(X_train, X_test, y_train, y_test)

# %%
df =pd.read_csv('../Datasets/ML_vars/0001.csv')
for i in range(1,18):
    stri=''
    if i<=8:
        stri+='0'+str(i)+'0'+str(i+1)
    elif i==9:
        stri+='0'+str(i)+str(i+1)
    else:
        stri+=str(i)+str(i+1)    
    temp_df=pd.read_csv('../Datasets/ML_vars/{}.csv'.format(stri))
    df=pd.concat([df,temp_df],sort =False)

# %%
df
# Out:
#      Unnamed: 0      Date        HomeTeam        AwayTeam  FTHG  FTAG  \
# 0             0  19/08/00        Charlton        Man City     4     0
# 1             1  19/08/00         Chelsea        West Ham     4     2
# 2             2  19/08/00        Coventry   Middlesbrough     1     3
# 3             3  19/08/00           Derby     Southampton     2     2
# 4             4  19/08/00           Leeds         Everton     2     0
# 5             5  19/08/00       Leicester     Aston Villa     0     0
# 6             6  19/08/00       Liverpool        Bradford     1     0
# 7             7  19/08/00      Sunderland         Arsenal     1     0
# 8             8  19/08/00       Tottenham         Ipswich     3     1
# 9             9  20/08/00      Man United       Newcastle     2     0
# 10           10  21/08/00         Arsenal       Liverpool     2     0
# 11           11  22/08/00        Bradford         Chelsea     2     0
# ...

# %%
Home = pd.get_dummies(df['HomeTeam'],drop_first=True)
Away = pd.get_dummies(df['AwayTeam'],drop_first=True)
df.drop(['HomeTeam','AwayTeam'],axis=1,inplace=True)
df = pd.concat([df,Home,Away],axis=1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'FTHG', 'FTAG', 'HomeResult', 'AwayResult',
#        'scoredhome', 'scoredaway', 'concededhome', 'concededaway', 'winshome',
#        'winsaway', 'Aston Villa', 'Birmingham', 'Blackburn', 'Blackpool',
#        'Bolton', 'Bournemouth', 'Bradford', 'Brighton', 'Burnley', 'Cardiff',
#        'Charlton', 'Chelsea', 'Coventry', 'Crystal Palace', 'Derby', 'Everton',
#        'Fulham', 'Huddersfield', 'Hull', 'Ipswich', 'Leeds', 'Leicester',
#        'Liverpool', 'Man City', 'Man United', 'Middlesboro', 'Middlesbrough',
#        'Newcastle', 'Norwich', 'Portsmouth', 'QPR', 'Reading',
#        'Sheffield United', 'Southampton', 'Stoke', 'Sunderland', 'Swansea',
#        'Tottenham', 'Watford', 'West Brom', 'West Ham', 'Wigan', 'Wolves',
#        'Aston Villa', 'Birmingham', 'Blackburn', 'Blackpool', 'Bolton',
#        'Bournemouth', 'Bradford', 'Brighton', 'Burnley', 'Cardiff', 'Charlton',
# ...

# %%
# X=df[['FTHG', 'FTAG', 'scoredhome', 'scoredaway', 'concededhome', 'concededaway',
#        'winshome', 'winsaway', 'Bournemouth', 'Brighton', 'Burnley', 'Cardiff',
#        'Chelsea', 'Crystal Palace', 'Everton', 'Fulham', 'Huddersfield',
#        'Leicester', 'Liverpool', 'Man City', 'Man United', 'Newcastle',
#        'Southampton', 'Tottenham', 'Watford', 'West Ham', 'Wolves',
#        'Bournemouth', 'Brighton', 'Burnley', 'Cardiff', 'Chelsea',
#        'Crystal Palace', 'Everton', 'Fulham', 'Huddersfield', 'Leicester',
#        'Liverpool', 'Man City', 'Man United', 'Newcastle', 'Southampton',
#        'Tottenham', 'Watford', 'West Ham', 'Wolves']]
X=df.drop(['Unnamed: 0', 'Date', 'HomeResult', 'AwayResult','FTHG','FTAG'],axis =1)

# %%
X.columns
# Out:
# Index(['scoredhome', 'scoredaway', 'concededhome', 'concededaway', 'winshome',
#        'winsaway', 'Aston Villa', 'Birmingham', 'Blackburn', 'Blackpool',
#        'Bolton', 'Bournemouth', 'Bradford', 'Brighton', 'Burnley', 'Cardiff',
#        'Charlton', 'Chelsea', 'Coventry', 'Crystal Palace', 'Derby', 'Everton',
#        'Fulham', 'Huddersfield', 'Hull', 'Ipswich', 'Leeds', 'Leicester',
#        'Liverpool', 'Man City', 'Man United', 'Middlesboro', 'Middlesbrough',
#        'Newcastle', 'Norwich', 'Portsmouth', 'QPR', 'Reading',
#        'Sheffield United', 'Southampton', 'Stoke', 'Sunderland', 'Swansea',
#        'Tottenham', 'Watford', 'West Brom', 'West Ham', 'Wigan', 'Wolves',
#        'Aston Villa', 'Birmingham', 'Blackburn', 'Blackpool', 'Bolton',
#        'Bournemouth', 'Bradford', 'Brighton', 'Burnley', 'Cardiff', 'Charlton',
#        'Chelsea', 'Coventry', 'Crystal Palace', 'Derby', 'Everton', 'Fulham',
# ...

# %%
y=df[['HomeResult']]*10

# %%
y=y.astype(int)

# %%
def svm(X_train, X_test, y_train, y_test):
    from sklearn.svm import SVC
    from sklearn.metrics import accuracy_score

    clf = SVC(kernel='linear')
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    print(accuracy_score(y_test,y_pred))
    from sklearn.metrics import classification_report
    print(classification_report(y_test,y_pred))
    from sklearn.metrics import confusion_matrix
    print(confusion_matrix(y_test,y_pred))
    score = logmodel.score(X_test, y_test)
    print(score)

# %%
def rand(X_train, X_test, y_train, y_test):
    from sklearn.ensemble import RandomForestClassifier

    #Create a Gaussian Classifier
    clf=RandomForestClassifier(n_estimators=100)
    #Train the model using the training sets y_pred=clf.predict(X_test)
    clf.fit(X_train,y_train)
    y_pred=clf.predict(X_test)
    print(accuracy_score(y_test,y_pred))
    from sklearn.metrics import classification_report
    print(classification_report(y_test,y_pred))
    from sklearn.metrics import confusion_matrix
    print(confusion_matrix(y_test,y_pred))
    score = clf.score(X_test, y_test)
    print(score)

# %%
train_test(X,y)
# Out:
# random forest
# /home/jushaan/Downloads/yes/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# 0.628167641325536
#               precision    recall  f1-score   support
#
#            0       0.62      0.64      0.63       589
#            5       0.47      0.26      0.34       504
#           10       0.67      0.81      0.73       959
#
#     accuracy                           0.63      2052
#    macro avg       0.59      0.57      0.57      2052
# weighted avg       0.61      0.63      0.61      2052
#
# [[378  67 144]
#  [132 132 240]
#  [ 96  84 779]]
# 0.628167641325536
